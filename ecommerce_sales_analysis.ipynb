# %%
import pandas as pd
import matplotlib.pyplot as plt

print("E-commerce Sales Analysis Project")
print("Project started successfully!")
import pandas as pd

data = {
    "Order_Date": [
        "2026-01-05", "2026-01-12", "2026-01-20",
        "2026-02-03", "2026-02-15", "2026-02-25",
        "2026-03-04", "2026-03-18", "2026-03-28",
        "2026-04-07", "2026-04-19", "2026-04-27"
    ],
    "Product": [
        "Laptop", "Mouse", "Keyboard",
        "Laptop", "Headphones", "Mouse",
        "Keyboard", "Laptop", "Headphones",
        "Mouse", "Laptop", "Keyboard"
    ],
    "Category": [
        "Electronics", "Accessories", "Accessories",
        "Electronics", "Accessories", "Accessories",
        "Accessories", "Electronics", "Accessories",
        "Accessories", "Electronics", "Accessories"
    ],
    "Quantity": [2, 10, 5, 3, 8, 12, 7, 2, 6, 15, 4, 9],
    "Sales": [120000, 10000, 15000, 180000, 24000, 12000,
              21000, 120000, 18000, 15000, 240000, 27000],
    "Profit": [18000, 3000, 4500, 27000, 6000, 3600,
               6300, 18000, 4500, 4500, 36000, 8100]
}

df = pd.DataFrame(data)

df["Order_Date"] = pd.to_datetime(df["Order_Date"])

print("Dataset created successfully!")
print("Rows:", len(df))
print("Columns:", len(df.columns))
# Check basic information
print("Dataset Information:")
print(df.info())

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Total Sales and Profit

total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()
total_quantity = df["Quantity"].sum()

print("Total Sales:", total_sales)
print("Total Profit:", total_profit)
print("Total Quantity Sold:", total_quantity)
# Best-selling products

product_sales = df.groupby("Product")["Sales"].sum().sort_values(ascending=False)

print("Sales by Product:")
print(product_sales)

print("\nBest-Selling Product:")
print(product_sales.idxmax())
# Sales by Category

category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)

print("Sales by Category:")
print(category_sales)
import matplotlib.pyplot as plt

category_sales.plot(kind="bar")

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales (₹)")
plt.xticks(rotation=0)
plt.show()
# Monthly Sales Analysis

df["Month"] = df["Order_Date"].dt.to_period("M").astype(str)

monthly_sales = df.groupby("Month")["Sales"].sum()

print("Monthly Sales:")
print(monthly_sales)
import matplotlib.pyplot as plt

monthly_sales.plot(kind="line", marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales (₹)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Key Business Insights

best_month = monthly_sales.idxmax()
best_month_sales = monthly_sales.max()

best_category = category_sales.idxmax()
best_category_sales = category_sales.max()

best_product = product_sales.idxmax()
best_product_sales = product_sales.max()

print("KEY BUSINESS INSIGHTS")
print("---------------------")
print("Best Sales Month:", best_month)
print("Best Month Sales: ₹", best_month_sales)

print("Best Category:", best_category)
print("Best Category Sales: ₹", best_category_sales)

print("Best-Selling Product:", best_product)
print("Best Product Sales: ₹", best_product_sales)
# Out:
# E-commerce Sales Analysis Project
# Project started successfully!
# Dataset created successfully!
# Rows: 12
# Columns: 6
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_Date  12 non-null     datetime64[ns]
#  1   Product     12 non-null     object
#  2   Category    12 non-null     object
#  3   Quantity    12 non-null     int64
#  4   Sales       12 non-null     int64
#  5   Profit      12 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 708.0+ bytes
# None
#
# Missing Values:
# Order_Date    0
# Product       0
# Category      0
# Quantity      0
# Sales         0
# Profit        0
# dtype: int64
#
# Duplicate Rows:
# 0
# Total Sales: 802000
# Total Profit: 139500
# Total Quantity Sold: 83
# Sales by Product:
# Product
# Laptop        660000
# Keyboard       63000
# ...
